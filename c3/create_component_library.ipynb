# %%
import os
import shutil

# %%
os.scandir('../component-library/')

# %%
# %%bash
# export version=0.1i
# for file in `find ../component-library/ -name "*.ipynb" |grep -vi test |grep -v checkpoints`
# do
#     ipython generate_kfp_component.ipynb $file $version 2>> log.txt >> log.txt
#     echo "Status:"$file:$? >> log.txt
# done

# %%
# %%bash
# export version=0.2h
# ipython generate_kfp_component.ipynb ../component-library/input/input-url.ipynb $version
# ipython generate_kfp_component.ipynb ../component-library/transform/spark-json-to-parquet.ipynb $version
# Out:
# input-url
# This component reads a file from a HTTP(s) source via wget CLAIMED v0.2h
# {'url': ('url of souce', 'String', None), 'data_dir': ('temporal data storage for local execution', 'String', " '../../data/'")}
# {'output_data': ('path and file name for output', 'String', " 'data.csv'")}
# ['pip install  wget==3.2 requests==2.28.1']
# ../component-library/input/input-url.ipynb
# FROM registry.access.redhat.com/ubi8/python-39
# RUN pip install ipython==8.6.0 nbformat==5.7.0
# RUN pip install  wget==3.2 requests==2.28.1
# ADD input-url.ipynb /opt/app-root/src/
# Sending build context to Docker daemon  749.1kB
# Step 1/4 : FROM registry.access.redhat.com/ubi8/python-39
#  ---> 54ab5aa3f6b8
# Step 2/4 : RUN pip install ipython==8.6.0 nbformat==5.7.0
#  ---> Using cache
#  ---> 0abe3c7d0edb
# Step 3/4 : RUN pip install  wget==3.2 requests==2.28.1
#  ---> Using cache
#  ---> f5d887f53545
# Step 4/4 : ADD input-url.ipynb /opt/app-root/src/
#  ---> 4d17bed0b748
# Successfully built 4d17bed0b748
# Successfully tagged claimed-input-url:0.2h
# The push refers to repository [docker.io/romeokienzler/claimed-input-url]
# 3fa4836abe7c: Preparing
# b2e1ede6680b: Preparing
# d9680a25182c: Preparing
# bd8ba0c9fb84: Preparing
# 2d6812ade9b7: Preparing
# 0ce645f59bfc: Preparing
# 9936c6aaa811: Preparing
# 5966005eac8d: Preparing
# 5966005eac8d: Waiting
# 0ce645f59bfc: Waiting
# 2d6812ade9b7: Layer already exists
# d9680a25182c: Layer already exists
# bd8ba0c9fb84: Layer already exists
# b2e1ede6680b: Layer already exists
# 0ce645f59bfc: Layer already exists
# 9936c6aaa811: Layer already exists
# 5966005eac8d: Layer already exists
# 3fa4836abe7c: Pushed
# 0.2h: digest: sha256:e85f1dc516c92fc1695a29f5db65ede69f0bc74941d58c89f2c727dbcfc5823a size: 2003
# name: input-url
# description: This component reads a file from a HTTP(s) source via wget CLAIMED v0.2h
#
# inputs:
# - {name: url, type: String, description: 'url of souce'}
# - {name: data_dir, type: String, description: 'temporal data storage for local execution'}
#
#
# outputs:
# - {name: output_data, type: String, description: 'path and file name for output'}
#
#
# implementation:
#     container:
#         image: romeokienzler/claimed-input-url:0.2h
#         command:
#         - sh
#         - -ec
#         - |
#           ipython ./input-url.ipynb output_data="$0" url="$1" data_dir="$2"
#         - {outputPath: output_data}
#         - {inputValue: url}
#         - {inputValue: data_dir}
#
# spark-json-to-parquet
# Converts a JSON file to parquet using ApacheSpark CLAIMED v0.2h
# {'data_json': ('source path and file name (default: data.csv)', 'String', " 'data.json'"), 'master': ('url of master (default: local mode)', 'String', ' "local[*]"'), 'data_dir': ('temporal data storage for local execution', 'String', " '../../data/'")}
# {'output_data_parquet': ('destination path and parquet file name (default: data.parquet)', 'String', " 'data.parquet'")}
# []
# ../component-library/transform/spark-json-to-parquet.ipynb
# FROM registry.access.redhat.com/ubi8/python-39
# RUN pip install ipython==8.6.0 nbformat==5.7.0
#
# ADD spark-json-to-parquet.ipynb /opt/app-root/src/
# Sending build context to Docker daemon  756.7kB
# Step 1/3 : FROM registry.access.redhat.com/ubi8/python-39
#  ---> 54ab5aa3f6b8
# Step 2/3 : RUN pip install ipython==8.6.0 nbformat==5.7.0
#  ---> Using cache
#  ---> 0abe3c7d0edb
# Step 3/3 : ADD spark-json-to-parquet.ipynb /opt/app-root/src/
#  ---> 24fef362ea11
# Successfully built 24fef362ea11
# Successfully tagged claimed-spark-json-to-parquet:0.2h
# The push refers to repository [docker.io/romeokienzler/claimed-spark-json-to-parquet]
# 047bce6a82bd: Preparing
# d9680a25182c: Preparing
# bd8ba0c9fb84: Preparing
# 2d6812ade9b7: Preparing
# 0ce645f59bfc: Preparing
# 9936c6aaa811: Preparing
# 5966005eac8d: Preparing
# 9936c6aaa811: Waiting
# 5966005eac8d: Waiting
# 0ce645f59bfc: Mounted from romeokienzler/claimed-input-url-01k
# bd8ba0c9fb84: Mounted from romeokienzler/claimed-input-url-01k
# d9680a25182c: Mounted from romeokienzler/claimed-input-url
# 2d6812ade9b7: Mounted from romeokienzler/claimed-input-url
# 9936c6aaa811: Mounted from romeokienzler/claimed-input-url
# 047bce6a82bd: Pushed
# 5966005eac8d: Mounted from romeokienzler/claimed-input-url-01k
# 0.2h: digest: sha256:d003db2489559db5f1821240cbdc1d6f02e3dc2598dd3aee7b38aee895648541 size: 1793
# name: spark-json-to-parquet
# description: Converts a JSON file to parquet using ApacheSpark CLAIMED v0.2h
#
# inputs:
# - {name: data_json, type: String, description: 'source path and file name (default: data.csv)'}
# - {name: master, type: String, description: 'url of master (default: local mode)'}
# - {name: data_dir, type: String, description: 'temporal data storage for local execution'}
#
#
# outputs:
# - {name: output_data_parquet, type: String, description: 'destination path and parquet file name (default: data.parquet)'}
#
#
# implementation:
#     container:
#         image: romeokienzler/claimed-spark-json-to-parquet:0.2h
#         command:
#         - sh
#         - -ec
#         - |
#           ipython ./spark-json-to-parquet.ipynb output_data_parquet="$0" data_json="$1" master="$2" data_dir="$3"
#         - {outputPath: output_data_parquet}
#         - {inputValue: data_json}
#         - {inputValue: master}
#         - {inputValue: data_dir}
