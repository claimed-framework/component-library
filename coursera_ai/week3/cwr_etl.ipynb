# %%
import numpy as np
import pandas as pd
import scipy.io as sio
import os

# %%
# !wget http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/97.mat
# !wget http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/98.mat
# !wget http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/99.mat
# !wget http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/100.mat
# Out:
# --2018-01-02 08:05:00--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/97.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3903344 (3.7M)
# Saving to: ‘97.mat’
#
# 100%[======================================>] 3,903,344   10.7MB/s   in 0.3s
#
# 2018-01-02 08:05:01 (10.7 MB/s) - ‘97.mat’ saved [3903344/3903344]
#
# --2018-01-02 08:05:01--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/98.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7742720 (7.4M)
# Saving to: ‘98.mat’
#
# 100%[======================================>] 7,742,720   12.6MB/s   in 0.6s
#
# 2018-01-02 08:05:01 (12.6 MB/s) - ‘98.mat’ saved [7742720/7742720]
#
# --2018-01-02 08:05:02--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/99.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15503928 (15M)
# Saving to: ‘99.mat’
#
# 100%[======================================>] 15,503,928  14.0MB/s   in 1.1s
#
# 2018-01-02 08:05:03 (14.0 MB/s) - ‘99.mat’ saved [15503928/15503928]
#
# --2018-01-02 08:05:03--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/100.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7770624 (7.4M)
# Saving to: ‘100.mat’
#
# 100%[======================================>] 7,770,624   9.67MB/s   in 0.8s
#
# 2018-01-02 08:05:04 (9.67 MB/s) - ‘100.mat’ saved [7770624/7770624]

# %%
# !mkdir  cwr_healthy

# %%
# !mv *.mat cwr_healthy/

# %%
def read_folder(folder):
    data = 'dummy'
    skip = False
    for file in os.listdir(folder):
        file_id = file[:-4]
        mat_file_dict = sio.loadmat(folder+file)
        del data
        for key, value in mat_file_dict.items():
            if 'DE_time' in key or 'FE_time' in key:
                a = np.array(mat_file_dict[key])
                try:
                    data
                except NameError:
                    data = a
                else:
                    if (data.shape[0] != a.shape[0]):
                        print 'skipping ' + file_id
                        skip = True
                        continue
                    data = np.hstack((data,a))
        if skip:
            skip=False
            continue
        id = np.repeat(file_id,data.shape[0])
        id.shape = (id.shape[0],1)
        data = np.hstack((id,data))
        if data.shape[1] == 2:
            zeros = np.repeat(float(0),data.shape[0])
            zeros.shape =(data.shape[0],1)
            data = np.hstack((data,zeros))
        try:
            result
        except NameError:
            result = data
        else:
            result = np.vstack((result,data))
    return result

# %%
result_healthy = read_folder('./cwr_healthy/')
# Out:
# skipping 99
# skipping 99

# %%
pdf = pd.DataFrame(result_healthy)

# %%
pdf.to_csv('result_healthy_pandas.csv', header=False, index=True)

# %%
# !for url in `curl -s csegroups.case.edu/bearingdatacenter/pages/12k-drive-end-bearing-fault-data |grep mat |grep http |awk -F'href="' '{print $2}' |awk -F'">' '{print $1}'`; do wget $url; done
# !for url in `curl -s csegroups.case.edu/bearingdatacenter/pages/48k-drive-end-bearing-fault-data |grep mat |grep http |awk -F'href="' '{print $2}' |awk -F'">' '{print $1}'`; do wget $url; done
# !for url in `curl -s csegroups.case.edu/bearingdatacenter/pages/12k-fan-end-bearing-fault-data |grep mat |grep http |awk -F'href="' '{print $2}' |awk -F'">' '{print $1}'`; do wget $url; done
# !mkdir cwr_faulty
# !mv *.mat cwr_faulty/
# Out:
# --2018-01-02 08:11:21--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/105.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2910768 (2.8M)
# Saving to: ‘105.mat’
#
# 100%[======================================>] 2,910,768   7.08MB/s   in 0.4s
#
# 2018-01-02 08:11:22 (7.08 MB/s) - ‘105.mat’ saved [2910768/2910768]
#
# --2018-01-02 08:11:22--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/118.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2942112 (2.8M)
# Saving to: ‘118.mat’
#
# 100%[======================================>] 2,942,112   5.65MB/s   in 0.5s
#
# 2018-01-02 08:11:22 (5.65 MB/s) - ‘118.mat’ saved [2942112/2942112]
#
# --2018-01-02 08:11:22--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/130.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘130.mat’
#
# 100%[======================================>] 2,928,192   6.44MB/s   in 0.4s
#
# 2018-01-02 08:11:23 (6.44 MB/s) - ‘130.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:11:23--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/144.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2935152 (2.8M)
# Saving to: ‘144.mat’
#
# 100%[======================================>] 2,935,152   6.09MB/s   in 0.5s
#
# 2018-01-02 08:11:23 (6.09 MB/s) - ‘144.mat’ saved [2935152/2935152]
#
# --2018-01-02 08:11:23--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/156.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2935152 (2.8M)
# Saving to: ‘156.mat’
#
# 100%[======================================>] 2,935,152   6.09MB/s   in 0.5s
#
# 2018-01-02 08:11:24 (6.09 MB/s) - ‘156.mat’ saved [2935152/2935152]
#
# --2018-01-02 08:11:24--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/106.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘106.mat’
#
# 100%[======================================>] 2,928,192   5.68MB/s   in 0.5s
#
# 2018-01-02 08:11:25 (5.68 MB/s) - ‘106.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:11:25--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/119.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2914248 (2.8M)
# Saving to: ‘119.mat’
#
# 100%[======================================>] 2,914,248   5.00MB/s   in 0.6s
#
# 2018-01-02 08:11:27 (5.00 MB/s) - ‘119.mat’ saved [2914248/2914248]
#
# --2018-01-02 08:11:27--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/131.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2938632 (2.8M)
# Saving to: ‘131.mat’
#
# 100%[======================================>] 2,938,632   2.19MB/s   in 1.3s
#
# 2018-01-02 08:11:28 (2.19 MB/s) - ‘131.mat’ saved [2938632/2938632]
#
# --2018-01-02 08:11:28--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/145.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘145.mat’
#
# 100%[======================================>] 2,924,712   2.08MB/s   in 1.3s
#
# 2018-01-02 08:11:30 (2.08 MB/s) - ‘145.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:11:30--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/158.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘158.mat’
#
# 100%[======================================>] 2,928,192   1.28MB/s   in 2.2s
#
# 2018-01-02 08:11:32 (1.28 MB/s) - ‘158.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:11:32--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/107.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘107.mat’
#
# 100%[======================================>] 2,931,672   1.44MB/s   in 1.9s
#
# 2018-01-02 08:11:34 (1.44 MB/s) - ‘107.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:11:34--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/120.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2917752 (2.8M)
# Saving to: ‘120.mat’
#
# 100%[======================================>] 2,917,752   1.65MB/s   in 1.7s
#
# 2018-01-02 08:11:36 (1.65 MB/s) - ‘120.mat’ saved [2917752/2917752]
#
# --2018-01-02 08:11:36--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/132.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2914248 (2.8M)
# Saving to: ‘132.mat’
#
# 100%[======================================>] 2,914,248   2.58MB/s   in 1.1s
#
# 2018-01-02 08:11:37 (2.58 MB/s) - ‘132.mat’ saved [2914248/2914248]
#
# --2018-01-02 08:11:37--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/146.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2917752 (2.8M)
# Saving to: ‘146.mat’
#
# 100%[======================================>] 2,917,752   3.90MB/s   in 0.7s
#
# 2018-01-02 08:11:38 (3.90 MB/s) - ‘146.mat’ saved [2917752/2917752]
#
# --2018-01-02 08:11:38--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/159.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2935152 (2.8M)
# Saving to: ‘159.mat’
#
# 100%[======================================>] 2,935,152   2.25MB/s   in 1.2s
#
# 2018-01-02 08:11:39 (2.25 MB/s) - ‘159.mat’ saved [2935152/2935152]
#
# --2018-01-02 08:11:39--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/108.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2950416 (2.8M)
# Saving to: ‘108.mat’
#
# 100%[======================================>] 2,950,416   3.12MB/s   in 0.9s
#
# 2018-01-02 08:11:40 (3.12 MB/s) - ‘108.mat’ saved [2950416/2950416]
#
# --2018-01-02 08:11:40--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/121.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2917752 (2.8M)
# Saving to: ‘121.mat’
#
# 100%[======================================>] 2,917,752   3.34MB/s   in 0.8s
#
# 2018-01-02 08:11:41 (3.34 MB/s) - ‘121.mat’ saved [2917752/2917752]
#
# --2018-01-02 08:11:41--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/133.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2942112 (2.8M)
# Saving to: ‘133.mat’
#
# 100%[======================================>] 2,942,112   2.68MB/s   in 1.0s
#
# 2018-01-02 08:11:42 (2.68 MB/s) - ‘133.mat’ saved [2942112/2942112]
#
# --2018-01-02 08:11:42--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/147.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2935152 (2.8M)
# Saving to: ‘147.mat’
#
# 100%[======================================>] 2,935,152   3.08MB/s   in 0.9s
#
# 2018-01-02 08:11:43 (3.08 MB/s) - ‘147.mat’ saved [2935152/2935152]
#
# --2018-01-02 08:11:43--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/160.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘160.mat’
#
# 100%[======================================>] 2,931,672   3.84MB/s   in 0.7s
#
# 2018-01-02 08:11:44 (3.84 MB/s) - ‘160.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:11:44--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/169.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘169.mat’
#
# 100%[======================================>] 2,924,712   4.45MB/s   in 0.6s
#
# 2018-01-02 08:11:45 (4.45 MB/s) - ‘169.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:11:45--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/185.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘185.mat’
#
# 100%[======================================>] 2,924,712   4.24MB/s   in 0.7s
#
# 2018-01-02 08:11:45 (4.24 MB/s) - ‘185.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:11:45--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/197.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘197.mat’
#
# 100%[======================================>] 2,924,712   4.99MB/s   in 0.6s
#
# 2018-01-02 08:11:46 (4.99 MB/s) - ‘197.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:11:46--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/170.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘170.mat’
#
# 100%[======================================>] 2,924,712   2.75MB/s   in 1.0s
#
# 2018-01-02 08:11:47 (2.75 MB/s) - ‘170.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:11:47--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/186.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘186.mat’
#
# 100%[======================================>] 2,931,672   3.86MB/s   in 0.7s
#
# 2018-01-02 08:11:48 (3.86 MB/s) - ‘186.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:11:48--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/198.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘198.mat’
#
# 100%[======================================>] 2,931,672   2.53MB/s   in 1.1s
#
# 2018-01-02 08:11:49 (2.53 MB/s) - ‘198.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:11:49--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/171.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘171.mat’
#
# 100%[======================================>] 2,924,712   3.49MB/s   in 0.8s
#
# 2018-01-02 08:11:50 (3.49 MB/s) - ‘171.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:11:50--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/187.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘187.mat’
#
# 100%[======================================>] 2,928,192   4.19MB/s   in 0.7s
#
# 2018-01-02 08:11:51 (4.19 MB/s) - ‘187.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:11:51--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/199.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘199.mat’
#
# 100%[======================================>] 2,924,712   2.75MB/s   in 1.0s
#
# 2018-01-02 08:11:52 (2.75 MB/s) - ‘199.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:11:52--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/172.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2921232 (2.8M)
# Saving to: ‘172.mat’
#
# 100%[======================================>] 2,921,232   3.71MB/s   in 0.8s
#
# 2018-01-02 08:11:53 (3.71 MB/s) - ‘172.mat’ saved [2921232/2921232]
#
# --2018-01-02 08:11:53--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/188.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘188.mat’
#
# 100%[======================================>] 2,931,672   4.71MB/s   in 0.6s
#
# 2018-01-02 08:11:53 (4.71 MB/s) - ‘188.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:11:53--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/200.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘200.mat’
#
# 100%[======================================>] 2,928,192   4.75MB/s   in 0.6s
#
# 2018-01-02 08:11:54 (4.75 MB/s) - ‘200.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:11:54--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/209.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘209.mat’
#
# 100%[======================================>] 2,931,672   5.65MB/s   in 0.5s
#
# 2018-01-02 08:11:55 (5.65 MB/s) - ‘209.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:11:55--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/222.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘222.mat’
#
# 100%[======================================>] 2,928,192   5.71MB/s   in 0.5s
#
# 2018-01-02 08:11:55 (5.71 MB/s) - ‘222.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:11:55--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/234.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2938632 (2.8M)
# Saving to: ‘234.mat’
#
# 100%[======================================>] 2,938,632   5.37MB/s   in 0.5s
#
# 2018-01-02 08:11:56 (5.37 MB/s) - ‘234.mat’ saved [2938632/2938632]
#
# --2018-01-02 08:11:56--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/246.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2921232 (2.8M)
# Saving to: ‘246.mat’
#
# 100%[======================================>] 2,921,232   5.32MB/s   in 0.5s
#
# 2018-01-02 08:11:56 (5.32 MB/s) - ‘246.mat’ saved [2921232/2921232]
#
# --2018-01-02 08:11:56--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/258.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘258.mat’
#
# 100%[======================================>] 2,924,712   6.03MB/s   in 0.5s
#
# 2018-01-02 08:11:57 (6.03 MB/s) - ‘258.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:11:57--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/210.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2917752 (2.8M)
# Saving to: ‘210.mat’
#
# 100%[======================================>] 2,917,752   5.72MB/s   in 0.5s
#
# 2018-01-02 08:11:57 (5.72 MB/s) - ‘210.mat’ saved [2917752/2917752]
#
# --2018-01-02 08:11:57--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/223.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2921232 (2.8M)
# Saving to: ‘223.mat’
#
# 100%[======================================>] 2,921,232   5.71MB/s   in 0.5s
#
# 2018-01-02 08:11:58 (5.71 MB/s) - ‘223.mat’ saved [2921232/2921232]
#
# --2018-01-02 08:11:58--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/235.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘235.mat’
#
# 100%[======================================>] 2,928,192   3.11MB/s   in 0.9s
#
# 2018-01-02 08:11:59 (3.11 MB/s) - ‘235.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:11:59--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/247.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘247.mat’
#
# 100%[======================================>] 2,928,192   2.52MB/s   in 1.1s
#
# 2018-01-02 08:12:00 (2.52 MB/s) - ‘247.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:12:00--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/259.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2938632 (2.8M)
# Saving to: ‘259.mat’
#
# 100%[======================================>] 2,938,632   1.89MB/s   in 1.5s
#
# 2018-01-02 08:12:02 (1.89 MB/s) - ‘259.mat’ saved [2938632/2938632]
#
# --2018-01-02 08:12:02--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/211.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2924712 (2.8M)
# Saving to: ‘211.mat’
#
# 100%[======================================>] 2,924,712   1.64MB/s   in 1.7s
#
# 2018-01-02 08:12:03 (1.64 MB/s) - ‘211.mat’ saved [2924712/2924712]
#
# --2018-01-02 08:12:03--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/224.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘224.mat’
#
# 100%[======================================>] 2,931,672   2.85MB/s   in 1.0s
#
# 2018-01-02 08:12:05 (2.85 MB/s) - ‘224.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:12:05--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/236.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2935152 (2.8M)
# Saving to: ‘236.mat’
#
# 100%[======================================>] 2,935,152   2.69MB/s   in 1.0s
#
# 2018-01-02 08:12:06 (2.69 MB/s) - ‘236.mat’ saved [2935152/2935152]
#
# --2018-01-02 08:12:06--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/248.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2935152 (2.8M)
# Saving to: ‘248.mat’
#
# 100%[======================================>] 2,935,152   3.40MB/s   in 0.8s
#
# 2018-01-02 08:12:07 (3.40 MB/s) - ‘248.mat’ saved [2935152/2935152]
#
# --2018-01-02 08:12:07--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/260.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2945592 (2.8M)
# Saving to: ‘260.mat’
#
# 100%[======================================>] 2,945,592   4.45MB/s   in 0.6s
#
# 2018-01-02 08:12:07 (4.45 MB/s) - ‘260.mat’ saved [2945592/2945592]
#
# --2018-01-02 08:12:07--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/212.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘212.mat’
#
# 100%[======================================>] 2,928,192   4.72MB/s   in 0.6s
#
# 2018-01-02 08:12:08 (4.72 MB/s) - ‘212.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:12:08--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/225.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘225.mat’
# 100%[======================================>] 2,931,672   5.02MB/s   in 0.6s
#
# 2018-01-02 08:12:09 (5.02 MB/s) - ‘225.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:12:09--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/237.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928192 (2.8M)
# Saving to: ‘237.mat’
#
# 100%[======================================>] 2,928,192   4.99MB/s   in 0.6s
#
# 2018-01-02 08:12:09 (4.99 MB/s) - ‘237.mat’ saved [2928192/2928192]
#
# --2018-01-02 08:12:09--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/249.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2931672 (2.8M)
# Saving to: ‘249.mat’
#
# 100%[======================================>] 2,931,672   5.01MB/s   in 0.6s
#
# 2018-01-02 08:12:10 (5.01 MB/s) - ‘249.mat’ saved [2931672/2931672]
#
# --2018-01-02 08:12:10--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/261.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2921232 (2.8M)
# Saving to: ‘261.mat’
#
# 100%[======================================>] 2,921,232   3.84MB/s   in 0.7s
#
# 2018-01-02 08:12:11 (3.84 MB/s) - ‘261.mat’ saved [2921232/2921232]
#
# --2018-01-02 08:12:11--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/3001.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 966608 (944K)
# Saving to: ‘3001.mat’
#
# 100%[======================================>] 966,608     3.08MB/s   in 0.3s
#
# 2018-01-02 08:12:11 (3.08 MB/s) - ‘3001.mat’ saved [966608/966608]
#
# --2018-01-02 08:12:11--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/3005.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 966608 (944K)
# Saving to: ‘3005.mat’
#
# 100%[======================================>] 966,608     2.90MB/s   in 0.3s
#
# 2018-01-02 08:12:11 (2.90 MB/s) - ‘3005.mat’ saved [966608/966608]
#
# --2018-01-02 08:12:11--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/3002.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 971008 (948K)
# Saving to: ‘3002.mat’
#
# 100%[======================================>] 971,008     3.09MB/s   in 0.3s
#
# 2018-01-02 08:12:12 (3.09 MB/s) - ‘3002.mat’ saved [971008/971008]
#
# --2018-01-02 08:12:12--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/3006.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 971008 (948K)
# Saving to: ‘3006.mat’
#
# 100%[======================================>] 971,008     3.07MB/s   in 0.3s
#
# 2018-01-02 08:12:12 (3.07 MB/s) - ‘3006.mat’ saved [971008/971008]
#
# --2018-01-02 08:12:12--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/3003.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 971008 (948K)
# Saving to: ‘3003.mat’
#
# 100%[======================================>] 971,008     3.09MB/s   in 0.3s
#
# 2018-01-02 08:12:12 (3.09 MB/s) - ‘3003.mat’ saved [971008/971008]
#
# --2018-01-02 08:12:13--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/3007.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 968072 (945K)
# Saving to: ‘3007.mat’
#
# 100%[======================================>] 968,072     2.33MB/s   in 0.4s
#
# 2018-01-02 08:12:13 (2.33 MB/s) - ‘3007.mat’ saved [968072/968072]
#
# --2018-01-02 08:12:13--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/3004.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 972480 (950K)
# Saving to: ‘3004.mat’
#
# 100%[======================================>] 972,480     2.44MB/s   in 0.4s
#
# 2018-01-02 08:12:13 (2.44 MB/s) - ‘3004.mat’ saved [972480/972480]
#
# --2018-01-02 08:12:13--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/3008.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 968072 (945K)
# Saving to: ‘3008.mat’
#
# 100%[======================================>] 968,072     2.53MB/s   in 0.4s
#
# 2018-01-02 08:12:14 (2.53 MB/s) - ‘3008.mat’ saved [968072/968072]
#
# --2018-01-02 08:12:14--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/109.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3903344 (3.7M)
# Saving to: ‘109.mat’
#
# 100%[======================================>] 3,903,344   4.09MB/s   in 0.9s
#
# 2018-01-02 08:12:15 (4.09 MB/s) - ‘109.mat’ saved [3903344/3903344]
#
# --2018-01-02 08:12:15--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/122.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3916160 (3.7M)
# Saving to: ‘122.mat’
#
# 100%[======================================>] 3,916,160   6.02MB/s   in 0.6s
#
# 2018-01-02 08:12:16 (6.02 MB/s) - ‘122.mat’ saved [3916160/3916160]
#
# --2018-01-02 08:12:16--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/135.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3896944 (3.7M)
# Saving to: ‘135.mat’
#
# 100%[======================================>] 3,896,944   4.60MB/s   in 0.8s
#
# 2018-01-02 08:12:17 (4.60 MB/s) - ‘135.mat’ saved [3896944/3896944]
#
# --2018-01-02 08:12:17--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/148.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1993968 (1.9M)
# Saving to: ‘148.mat’
#
# 100%[======================================>] 1,993,968   4.81MB/s   in 0.4s
#
# 2018-01-02 08:12:17 (4.81 MB/s) - ‘148.mat’ saved [1993968/1993968]
#
# --2018-01-02 08:12:17--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/161.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2079840 (2.0M)
# Saving to: ‘161.mat’
#
# 100%[======================================>] 2,079,840   4.99MB/s   in 0.4s
#
# 2018-01-02 08:12:18 (4.99 MB/s) - ‘161.mat’ saved [2079840/2079840]
#
# --2018-01-02 08:12:18--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/110.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7779920 (7.4M)
# Saving to: ‘110.mat’
#
# 100%[======================================>] 7,779,920   8.02MB/s   in 0.9s
#
# 2018-01-02 08:12:19 (8.02 MB/s) - ‘110.mat’ saved [7779920/7779920]
#
# --2018-01-02 08:12:19--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/123.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7798480 (7.4M)
# Saving to: ‘123.mat’
#
# 100%[======================================>] 7,798,480   6.14MB/s   in 1.2s
#
# 2018-01-02 08:12:20 (6.14 MB/s) - ‘123.mat’ saved [7798480/7798480]
#
# --2018-01-02 08:12:20--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/136.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7789200 (7.4M)
# Saving to: ‘136.mat’
#
# 100%[======================================>] 7,789,200   8.66MB/s   in 0.9s
#
# 2018-01-02 08:12:21 (8.66 MB/s) - ‘136.mat’ saved [7789200/7789200]
#
# --2018-01-02 08:12:21--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/149.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7761344 (7.4M)
# Saving to: ‘149.mat’
#
# 100%[======================================>] 7,761,344   7.88MB/s   in 0.9s
#
# 2018-01-02 08:12:22 (7.88 MB/s) - ‘149.mat’ saved [7761344/7761344]
#
# --2018-01-02 08:12:22--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/162.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7724208 (7.4M)
# Saving to: ‘162.mat’
#
# 100%[======================================>] 7,724,208   6.23MB/s   in 1.2s
#
# 2018-01-02 08:12:23 (6.23 MB/s) - ‘162.mat’ saved [7724208/7724208]
#
# --2018-01-02 08:12:23--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/111.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7770624 (7.4M)
# Saving to: ‘111.mat’
#
# 100%[======================================>] 7,770,624   3.50MB/s   in 2.1s
#
# 2018-01-02 08:12:25 (3.50 MB/s) - ‘111.mat’ saved [7770624/7770624]
#
# --2018-01-02 08:12:25--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/124.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7789200 (7.4M)
# Saving to: ‘124.mat’
#
# 100%[======================================>] 7,789,200   3.03MB/s   in 2.5s
#
# 2018-01-02 08:12:28 (3.03 MB/s) - ‘124.mat’ saved [7789200/7789200]
#
# --2018-01-02 08:12:28--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/137.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7789200 (7.4M)
# Saving to: ‘137.mat’
#
# 100%[======================================>] 7,789,200   5.34MB/s   in 1.4s
#
# 2018-01-02 08:12:29 (5.34 MB/s) - ‘137.mat’ saved [7789200/7789200]
#
# --2018-01-02 08:12:29--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/150.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7770624 (7.4M)
# Saving to: ‘150.mat’
#
# 100%[======================================>] 7,770,624   7.38MB/s   in 1.0s
#
# 2018-01-02 08:12:30 (7.38 MB/s) - ‘150.mat’ saved [7770624/7770624]
#
# --2018-01-02 08:12:30--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/163.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7733504 (7.4M)
# Saving to: ‘163.mat’
#
# 100%[======================================>] 7,733,504   10.5MB/s   in 0.7s
#
# 2018-01-02 08:12:31 (10.5 MB/s) - ‘163.mat’ saved [7733504/7733504]
#
# --2018-01-02 08:12:31--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/112.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7770624 (7.4M)
# Saving to: ‘112.mat’
#
# 100%[======================================>] 7,770,624   9.67MB/s   in 0.8s
#
# 2018-01-02 08:12:32 (9.67 MB/s) - ‘112.mat’ saved [7770624/7770624]
#
# --2018-01-02 08:12:32--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/125.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7817056 (7.5M)
# Saving to: ‘125.mat’
#
# 100%[======================================>] 7,817,056   11.2MB/s   in 0.7s
#
# 2018-01-02 08:12:33 (11.2 MB/s) - ‘125.mat’ saved [7817056/7817056]
#
# --2018-01-02 08:12:33--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/138.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7807760 (7.4M)
# Saving to: ‘138.mat’
#
# 100%[======================================>] 7,807,760   11.6MB/s   in 0.6s
#
# 2018-01-02 08:12:33 (11.6 MB/s) - ‘138.mat’ saved [7807760/7807760]
#
# --2018-01-02 08:12:33--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/151.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7779920 (7.4M)
# Saving to: ‘151.mat’
#
# 100%[======================================>] 7,779,920   10.6MB/s   in 0.7s
#
# 2018-01-02 08:12:34 (10.6 MB/s) - ‘151.mat’ saved [7779920/7779920]
#
# --2018-01-02 08:12:34--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/164.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7752064 (7.4M)
# Saving to: ‘164.mat’
#
# 100%[======================================>] 7,752,064   8.82MB/s   in 0.8s
#
# 2018-01-02 08:12:35 (8.82 MB/s) - ‘164.mat’ saved [7752064/7752064]
#
# --2018-01-02 08:12:35--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/174.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1020944 (997K)
# Saving to: ‘174.mat’
#
# 100%[======================================>] 1,020,944   4.46MB/s   in 0.2s
#
# 2018-01-02 08:12:35 (4.46 MB/s) - ‘174.mat’ saved [1020944/1020944]
#
# --2018-01-02 08:12:35--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/189.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3986672 (3.8M)
# Saving to: ‘189.mat’
#
# 100%[======================================>] 3,986,672   6.06MB/s   in 0.6s
#
# 2018-01-02 08:12:36 (6.06 MB/s) - ‘189.mat’ saved [3986672/3986672]
#
# --2018-01-02 08:12:36--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/201.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3922576 (3.7M)
# Saving to: ‘201.mat’
#
# 100%[======================================>] 3,922,576   7.10MB/s   in 0.5s
#
# 2018-01-02 08:12:37 (7.10 MB/s) - ‘201.mat’ saved [3922576/3922576]
#
# --2018-01-02 08:12:37--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/175.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17849704 (17M)
# Saving to: ‘175.mat’
#
# 100%[======================================>] 17,849,704  11.5MB/s   in 1.5s
#
# 2018-01-02 08:12:38 (11.5 MB/s) - ‘175.mat’ saved [17849704/17849704]
#
# --2018-01-02 08:12:38--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/190.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7779920 (7.4M)
# Saving to: ‘190.mat’
#
# 100%[======================================>] 7,779,920   10.2MB/s   in 0.7s
#
# 2018-01-02 08:12:39 (10.2 MB/s) - ‘190.mat’ saved [7779920/7779920]
#
# --2018-01-02 08:12:39--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/202.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7752064 (7.4M)
# Saving to: ‘202.mat’
#
# 100%[======================================>] 7,752,064   11.1MB/s   in 0.7s
#
# 2018-01-02 08:12:40 (11.1 MB/s) - ‘202.mat’ saved [7752064/7752064]
#
# --2018-01-02 08:12:40--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/176.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7807760 (7.4M)
# Saving to: ‘176.mat’
#
# 100%[======================================>] 7,807,760   6.63MB/s   in 1.1s
#
# 2018-01-02 08:12:41 (6.63 MB/s) - ‘176.mat’ saved [7807760/7807760]
#
# --2018-01-02 08:12:41--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/191.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7798480 (7.4M)
# Saving to: ‘191.mat’
#
# 100%[======================================>] 7,798,480   9.22MB/s   in 0.8s
#
# 2018-01-02 08:12:42 (9.22 MB/s) - ‘191.mat’ saved [7798480/7798480]
#
# --2018-01-02 08:12:42--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/203.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7789200 (7.4M)
# Saving to: ‘203.mat’
#
# 100%[======================================>] 7,789,200   10.0MB/s   in 0.7s
#
# 2018-01-02 08:12:43 (10.0 MB/s) - ‘203.mat’ saved [7789200/7789200]
#
# --2018-01-02 08:12:43--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/177.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7761344 (7.4M)
# Saving to: ‘177.mat’
#
# 100%[======================================>] 7,761,344   10.4MB/s   in 0.7s
#
# 2018-01-02 08:12:44 (10.4 MB/s) - ‘177.mat’ saved [7761344/7761344]
#
# --2018-01-02 08:12:44--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/192.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7789200 (7.4M)
# Saving to: ‘192.mat’
#
# 100%[======================================>] 7,789,200   8.54MB/s   in 0.9s
#
# 2018-01-02 08:12:45 (8.54 MB/s) - ‘192.mat’ saved [7789200/7789200]
#
# --2018-01-02 08:12:45--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/204.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7817056 (7.5M)
# Saving to: ‘204.mat’
#
# 100%[======================================>] 7,817,056   9.82MB/s   in 0.8s
#
# 2018-01-02 08:12:45 (9.82 MB/s) - ‘204.mat’ saved [7817056/7817056]
#
# --2018-01-02 08:12:45--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/213.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3909760 (3.7M)
# Saving to: ‘213.mat’
#
# 100%[======================================>] 3,909,760   6.65MB/s   in 0.6s
#
# 2018-01-02 08:12:46 (6.65 MB/s) - ‘213.mat’ saved [3909760/3909760]
#
# --2018-01-02 08:12:46--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/226.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3903344 (3.7M)
# Saving to: ‘226.mat’
#
# 100%[======================================>] 3,903,344   7.14MB/s   in 0.5s
#
# 2018-01-02 08:12:47 (7.14 MB/s) - ‘226.mat’ saved [3903344/3903344]
#
# --2018-01-02 08:12:47--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/238.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3941808 (3.8M)
# Saving to: ‘238.mat’
#
# ...
# HTTP request sent, awaiting response... 200 OK
# Length: 2926056 (2.8M)
# Saving to: ‘300.mat’
#
# 100%[======================================>] 2,926,056   4.47MB/s   in 0.6s
#
# 2018-01-02 08:13:15 (4.47 MB/s) - ‘300.mat’ saved [2926056/2926056]
#
# --2018-01-02 08:13:15--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/306.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2921664 (2.8M)
# Saving to: ‘306.mat’
#
# 100%[======================================>] 2,921,664   4.76MB/s   in 0.6s
#
# 2018-01-02 08:13:16 (4.76 MB/s) - ‘306.mat’ saved [2921664/2921664]
#
# --2018-01-02 08:13:16--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/281.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2917248 (2.8M)
# Saving to: ‘281.mat’
#
# 100%[======================================>] 2,917,248   4.91MB/s   in 0.6s
#
# 2018-01-02 08:13:16 (4.91 MB/s) - ‘281.mat’ saved [2917248/2917248]
#
# --2018-01-02 08:13:16--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/285.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2908440 (2.8M)
# Saving to: ‘285.mat’
#
# 100%[======================================>] 2,908,440   2.02MB/s   in 1.4s
#
# 2018-01-02 08:13:18 (2.02 MB/s) - ‘285.mat’ saved [2908440/2908440]
#
# --2018-01-02 08:13:18--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/297.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2926056 (2.8M)
# Saving to: ‘297.mat’
#
# 100%[======================================>] 2,926,056   2.78MB/s   in 1.0s
#
# 2018-01-02 08:13:19 (2.78 MB/s) - ‘297.mat’ saved [2926056/2926056]
#
# --2018-01-02 08:13:19--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/301.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2921664 (2.8M)
# Saving to: ‘301.mat’
#
# 100%[======================================>] 2,921,664   1.75MB/s   in 1.6s
#
# 2018-01-02 08:13:21 (1.75 MB/s) - ‘301.mat’ saved [2921664/2921664]
#
# --2018-01-02 08:13:21--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/307.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2908440 (2.8M)
# Saving to: ‘307.mat’
#
# 100%[======================================>] 2,908,440   2.42MB/s   in 1.1s
#
# 2018-01-02 08:13:22 (2.42 MB/s) - ‘307.mat’ saved [2908440/2908440]
#
# --2018-01-02 08:13:22--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/274.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2912832 (2.8M)
# Saving to: ‘274.mat’
#
# 100%[======================================>] 2,912,832   3.34MB/s   in 0.8s
#
# 2018-01-02 08:13:23 (3.34 MB/s) - ‘274.mat’ saved [2912832/2912832]
#
# --2018-01-02 08:13:23--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/286.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2930472 (2.8M)
# Saving to: ‘286.mat’
#
# 100%[======================================>] 2,930,472   4.43MB/s   in 0.6s
#
# 2018-01-02 08:13:24 (4.43 MB/s) - ‘286.mat’ saved [2930472/2930472]
#
# --2018-01-02 08:13:24--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/313.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2904024 (2.8M)
# Saving to: ‘313.mat’
#
# 100%[======================================>] 2,904,024   4.41MB/s   in 0.6s
#
# 2018-01-02 08:13:24 (4.41 MB/s) - ‘313.mat’ saved [2904024/2904024]
#
# --2018-01-02 08:13:24--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/310.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2917248 (2.8M)
# Saving to: ‘310.mat’
#
# 100%[======================================>] 2,917,248   4.47MB/s   in 0.6s
#
# 2018-01-02 08:13:25 (4.47 MB/s) - ‘310.mat’ saved [2917248/2917248]
#
# --2018-01-02 08:13:25--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/275.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2912832 (2.8M)
# Saving to: ‘275.mat’
#
# 100%[======================================>] 2,912,832   2.95MB/s   in 0.9s
#
# 2018-01-02 08:13:26 (2.95 MB/s) - ‘275.mat’ saved [2912832/2912832]
#
# --2018-01-02 08:13:26--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/287.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2921664 (2.8M)
# Saving to: ‘287.mat’
#
# 100%[======================================>] 2,921,664   3.83MB/s   in 0.7s
#
# 2018-01-02 08:13:27 (3.83 MB/s) - ‘287.mat’ saved [2921664/2921664]
#
# --2018-01-02 08:13:27--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/309.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2908440 (2.8M)
# Saving to: ‘309.mat’
#
# 100%[======================================>] 2,908,440   4.42MB/s   in 0.6s
#
# 2018-01-02 08:13:27 (4.42 MB/s) - ‘309.mat’ saved [2908440/2908440]
#
# --2018-01-02 08:13:27--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/276.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2912832 (2.8M)
# Saving to: ‘276.mat’
#
# 100%[======================================>] 2,912,832   3.77MB/s   in 0.7s
#
# 2018-01-02 08:13:28 (3.77 MB/s) - ‘276.mat’ saved [2912832/2912832]
#
# --2018-01-02 08:13:28--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/288.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2934864 (2.8M)
# Saving to: ‘288.mat’
#
# 100%[======================================>] 2,934,864   4.73MB/s   in 0.6s
#
# 2018-01-02 08:13:29 (4.73 MB/s) - ‘288.mat’ saved [2934864/2934864]
#
# --2018-01-02 08:13:29--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/311.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2904024 (2.8M)
# Saving to: ‘311.mat’
#
# 100%[======================================>] 2,904,024   3.35MB/s   in 0.8s
#
# 2018-01-02 08:13:30 (3.35 MB/s) - ‘311.mat’ saved [2904024/2904024]
#
# --2018-01-02 08:13:30--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/277.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2928496 (2.8M)
# Saving to: ‘277.mat’
#
# 100%[======================================>] 2,928,496   3.18MB/s   in 0.9s
#
# 2018-01-02 08:13:31 (3.18 MB/s) - ‘277.mat’ saved [2928496/2928496]
#
# --2018-01-02 08:13:31--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/289.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2908440 (2.8M)
# Saving to: ‘289.mat’
#
# 100%[======================================>] 2,908,440   3.48MB/s   in 0.8s
#
# 2018-01-02 08:13:32 (3.48 MB/s) - ‘289.mat’ saved [2908440/2908440]
#
# --2018-01-02 08:13:32--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/312.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2904024 (2.8M)
# Saving to: ‘312.mat’
#
# 100%[======================================>] 2,904,024   4.17MB/s   in 0.7s
#
# 2018-01-02 08:13:32 (4.17 MB/s) - ‘312.mat’ saved [2904024/2904024]
#
# --2018-01-02 08:13:32--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/270.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2908440 (2.8M)
# Saving to: ‘270.mat’
#
# 100%[======================================>] 2,908,440   4.39MB/s   in 0.6s
#
# 2018-01-02 08:13:33 (4.39 MB/s) - ‘270.mat’ saved [2908440/2908440]
#
# --2018-01-02 08:13:33--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/290.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2912832 (2.8M)
# Saving to: ‘290.mat’
# 100%[======================================>] 2,912,832   4.09MB/s   in 0.7s
#
# 2018-01-02 08:13:34 (4.09 MB/s) - ‘290.mat’ saved [2912832/2912832]
#
# --2018-01-02 08:13:34--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/315.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2895216 (2.8M)
# Saving to: ‘315.mat’
#
# 100%[======================================>] 2,895,216   5.01MB/s   in 0.6s
#
# 2018-01-02 08:13:35 (5.01 MB/s) - ‘315.mat’ saved [2895216/2895216]
#
# --2018-01-02 08:13:35--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/271.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2908440 (2.8M)
# Saving to: ‘271.mat’
#
# 100%[======================================>] 2,908,440   4.66MB/s   in 0.6s
#
# 2018-01-02 08:13:35 (4.66 MB/s) - ‘271.mat’ saved [2908440/2908440]
#
# --2018-01-02 08:13:35--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/291.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2912832 (2.8M)
# Saving to: ‘291.mat’
#
# 100%[======================================>] 2,912,832   5.00MB/s   in 0.6s
#
# 2018-01-02 08:13:36 (5.00 MB/s) - ‘291.mat’ saved [2912832/2912832]
#
# --2018-01-02 08:13:36--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/316.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2895216 (2.8M)
# Saving to: ‘316.mat’
#
# 100%[======================================>] 2,895,216   4.95MB/s   in 0.6s
#
# 2018-01-02 08:13:36 (4.95 MB/s) - ‘316.mat’ saved [2895216/2895216]
#
# --2018-01-02 08:13:36--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/272.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2904024 (2.8M)
# Saving to: ‘272.mat’
#
# 100%[======================================>] 2,904,024   4.66MB/s   in 0.6s
#
# 2018-01-02 08:13:37 (4.66 MB/s) - ‘272.mat’ saved [2904024/2904024]
#
# --2018-01-02 08:13:37--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/292.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2917248 (2.8M)
# Saving to: ‘292.mat’
#
# 100%[======================================>] 2,917,248   4.50MB/s   in 0.6s
#
# 2018-01-02 08:13:38 (4.50 MB/s) - ‘292.mat’ saved [2917248/2917248]
#
# --2018-01-02 08:13:38--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/317.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2895216 (2.8M)
# Saving to: ‘317.mat’
#
# 100%[======================================>] 2,895,216   2.64MB/s   in 1.0s
#
# 2018-01-02 08:13:39 (2.64 MB/s) - ‘317.mat’ saved [2895216/2895216]
#
# --2018-01-02 08:13:39--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/273.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2908440 (2.8M)
# Saving to: ‘273.mat’
#
# 100%[======================================>] 2,908,440   3.46MB/s   in 0.8s
#
# 2018-01-02 08:13:40 (3.46 MB/s) - ‘273.mat’ saved [2908440/2908440]
#
# --2018-01-02 08:13:40--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/293.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2899632 (2.8M)
# Saving to: ‘293.mat’
#
# 100%[======================================>] 2,899,632   4.17MB/s   in 0.7s
#
# 2018-01-02 08:13:41 (4.17 MB/s) - ‘293.mat’ saved [2899632/2899632]
#
# --2018-01-02 08:13:41--  http://csegroups.case.edu/sites/default/files/bearingdatacenter/files/Datafiles/318.mat
# Resolving csegroups.case.edu (csegroups.case.edu)... 129.22.25.84
# Connecting to csegroups.case.edu (csegroups.case.edu)|129.22.25.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2912832 (2.8M)
# Saving to: ‘318.mat’
#
# 100%[======================================>] 2,912,832   4.69MB/s   in 0.6s
#
# 2018-01-02 08:13:41 (4.69 MB/s) - ‘318.mat’ saved [2912832/2912832]

# %%
# !ls cwr_faulty/
# Out:
# 105.mat  135.mat  169.mat  201.mat  234.mat  262.mat  286.mat	3007.mat
# 106.mat  136.mat  170.mat  202.mat  235.mat  263.mat  287.mat	3008.mat
# 107.mat  137.mat  171.mat  203.mat  236.mat  264.mat  288.mat	300.mat
# 108.mat  138.mat  172.mat  204.mat  237.mat  265.mat  289.mat	301.mat
# 109.mat  144.mat  174.mat  209.mat  238.mat  270.mat  290.mat	302.mat
# 110.mat  145.mat  175.mat  210.mat  239.mat  271.mat  291.mat	305.mat
# 111.mat  146.mat  176.mat  211.mat  240.mat  272.mat  292.mat	306.mat
# 112.mat  147.mat  177.mat  212.mat  241.mat  273.mat  293.mat	307.mat
# 118.mat  148.mat  185.mat  213.mat  246.mat  274.mat  294.mat	309.mat
# 119.mat  149.mat  186.mat  214.mat  247.mat  275.mat  295.mat	310.mat
# 120.mat  150.mat  187.mat  215.mat  248.mat  276.mat  296.mat	311.mat
# 121.mat  151.mat  188.mat  217.mat  249.mat  277.mat  297.mat	312.mat
# 122.mat  156.mat  189.mat  222.mat  250.mat  278.mat  298.mat	313.mat
# 123.mat  158.mat  190.mat  223.mat  251.mat  279.mat  299.mat	315.mat
# 124.mat  159.mat  191.mat  224.mat  252.mat  280.mat  3001.mat	316.mat
# 125.mat  160.mat  192.mat  225.mat  253.mat  281.mat  3002.mat	317.mat
# 130.mat  161.mat  197.mat  226.mat  258.mat  282.mat  3003.mat	318.mat
# 131.mat  162.mat  198.mat  227.mat  259.mat  283.mat  3004.mat
# 132.mat  163.mat  199.mat  228.mat  260.mat  284.mat  3005.mat
# 133.mat  164.mat  200.mat  229.mat  261.mat  285.mat  3006.mat

# %%
result_faulty = read_folder('./cwr_faulty/')
# Out:
# skipping 175
# skipping 175
# skipping 217
# skipping 217

# %%
pdf = pd.DataFrame(result_faulty)

# %%
pdf.to_csv('result_faulty_pandas.csv', header=False, index=True)

# %%
df_healhty = spark.read.csv('result_healthy_pandas.csv')
df_healhty.createOrReplaceTempView('df_healhty')

# %%
spark.sql('select _c1,count(_c1) as cn from df_healhty group by _c1 order by cn asc').show()
# Out:
# +---+------+
# |_c1|    cn|
# +---+------+
# | 97|243938|
# | 98|483903|
# |100|485643|
# +---+------+

# %%
df_faulty = spark.read.csv('result_faulty_pandas.csv')
df_faulty.createOrReplaceTempView('df_faulty')

# %%
spark.sql('select _c1,count(_c1) as cn from df_faulty group by _c1 order by cn asc').show()
# Out:
# +----+------+
# | _c1|    cn|
# +----+------+
# | 174| 63788|
# | 315|120617|
# | 317|120617|
# | 316|120617|
# |3005|120801|
# | 293|120801|
# |3001|120801|
# | 283|120801|
# | 313|120984|
# | 272|120984|
# | 305|120984|
# |3007|120984|
# |3008|120984|
# | 312|120984|
# | 298|120984|
# | 311|120984|
# | 309|121168|
# | 282|121168|
# | 302|121168|
# | 307|121168|
# +----+------+
# only showing top 20 rows

# %%
import ibmos2spark

# @hidden_cell
credentials = {
    'auth_url': 'https://identity.open.softlayer.com',
    'project_id': '6aaf54352357483486ee2d4981f8ef15',
    'region': 'dallas',
    'user_id': 'e8a574f22ee84d29b7a1987b6103fced',
    'username': 'member_adcb54bd899a7e39e31582bccad1577f68f1992f',
    'password': 'P*/m8,!#7s6H9poz'
}

configuration_name = 'os_d3bd5b94a9334de59a55a7fed2bedeaa_configs'
bmos = ibmos2spark.bluemix(sc, credentials, configuration_name)

from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
df_healhty.write.parquet(bmos.url('courseraai', 'cwr_healthy1.parquet'))

# %%
df_faulty.write.parquet(bmos.url('courseraai', 'cwr_faulty1.parquet'))

# %%
df_faulty.count()
# Out:
# 33317611
