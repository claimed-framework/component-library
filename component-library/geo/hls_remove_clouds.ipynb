# %% [markdown]
# geo-hls-remove-clouds

# %% [markdown]
# Removes clouds from HLS data

# %%
# !pip install xarray matplotlib geopandas rioxarray numpy shapely rasterio pyproj ipython dask distributed jinja2 bokeh

# %%
import os
from glob import glob

import matplotlib.pyplot as plt
import geopandas as gpd
import rasterio as rio
import xarray as xr
import rioxarray as rxr
import numpy as np
import glob
from shapely.geometry import mapping
import pyproj
from pyproj import Proj
from shapely.ops import transform
import logging
import re
import sys
from dask.distributed import Client

# %%
# path for input
input_dir=os.environ.get('input_dir','/home/romeokienzler/Downloads/HLS2022/HLS/**/')

# path for output
output_dir=os.environ.get('output_dir','/home/romeokienzler/Downloads/HLSS30.CF2/')

# file filter pattern
file_filter_pattern=os.environ.get('file_filter_pattern','HLS.S30*0.B*tif')
file_filter_pattern='HLS.S30.T15STU.2022171T165901.v2.0.B01.tif'

# %%
root = logging.getLogger()
root.setLevel(logging.DEBUG)

handler = logging.StreamHandler(sys.stdout)
handler.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)
root.addHandler(handler)

parameters = list(
    map(lambda s: re.sub('$', '"', s),
        map(
            lambda s: s.replace('=', '="'),
            filter(
                lambda s: s.find('=') > -1 and bool(re.match(r'[A-Za-z0-9_]*=[.\/A-Za-z0-9]*', s)),
                sys.argv
            )
    )))

for parameter in parameters:
    logging.debug('Parameter: ' + parameter)
    exec(parameter)

# %%
client = Client(n_workers=8, threads_per_worker=1, memory_limit='8GB')
client
# Out:
# 2023-06-21 17:02:30,236 - asyncio - DEBUG - Using selector: EpollSelector
# <Client: 'tcp://127.0.0.1:45941' processes=8 threads=8, memory=59.60 GiB>

# %%
def open_clean_band(band_path, crop_layer=None):
    """A function that opens a Landsat/Sentinel band as an (rio)xarray object

    Parameters
    ----------
    band_path : list
        A list of paths to the tif files that you wish to combine.

    crop_layer : geopandas geodataframe
        A geodataframe containing the clip extent of interest. NOTE: this will 
        fail if the clip extent is in a different CRS than the raster data.

    Returns
    -------
    An single xarray object with the Landsat band data.

    """

    if crop_layer is not None:
        try:
            clip_bound = crop_layer.geometry
            cleaned_band = rxr.open_rasterio(band_path,
                                             masked=True).rio.clip(clip_bound,
                                                                   from_disk=True).squeeze()
        except Exception as err:
            print("Oops, I need a geodataframe object for this to work.")
            print(err)
    else:
        cleaned_band = rxr.open_rasterio(band_path,
                                         masked=True).squeeze()

    return cleaned_band


def process_bands(paths, crop_layer=None, stack=False):
    """
    Open, clean and crop a list of raster files using rioxarray.

    Parameters
    ----------
    paths : list
        A list of paths to raster files that could be stacked (of the same 
        resolution, crs and spatial extent).

    crop_layer : geodataframe
        A geodataframe containing the crop geometry that you wish to crop your
        data to.

    stack : boolean
        If True, return a stacked xarray object. If false will return a list
        of xarray objects.

    Returns
    -------
        Either a list of xarray objects or a stacked xarray object
    """

    all_bands = []
    for i, aband in enumerate(paths):
        cleaned = open_clean_band(aband, crop_layer)
        cleaned["band"] = i+1
        all_bands.append(cleaned)

    if stack:
        print("I'm stacking your data now.")
        return xr.concat(all_bands, dim="band")
    else:
        print("Returning a list of xarray objects.")
        return all_bands

def good_quality(list_of_files, list_of_masks):
    """
    Open list of files and the corresponding list of masks for a bive satellite and remove all pixels that are cloud contaimated as flagged by the cloud mask
    Parameters
    ----------
    list of files : list
        A list of paths to files that could be stacked (of the same 
        resolution, crs and spatial extent).

    list-of_masks : list
        A list od ptahs to the maks for  each of the files listed above

    Returns
    -------
        Either a pixel values that are valid for a given satellite.
    """
    bitword_order = (1, 1, 1, 1, 1, 1, 2)  # set the number of bits per bitword
    num_bitwords = len(bitword_order)      # Define the number of bitwords based on your input above
    total_bits = sum(bitword_order)        # Should be 8, 16, or 32 depending on datatype
    list_of_files1.sort()
    list_of_masks1.sort()
    
    stacked_list=process_bands(list_of_files1,crop_layer=None, stack=True)
    stacked_masks=process_bands(list_of_masks1,crop_layer=None, stack=True)
            
    qVals = list(np.unique(stacked_masks))  # Create a list of unique values that need to be converted to binary and decoded
    qVals = [0 if x != x else x for x in qVals]
            
    all_bits = list()
    goodQuality = []
    for v in qVals:
        all_bits = []
        bits = total_bits
        i = 0

    # Convert to binary based on the values and # of bits defined above:
        bit_val = format(int(v), "b").zfill(bits)
       #print('\n' + str(v) + ' = ' + str(bit_val))
        all_bits.append(str(v) + ' = ' + str(bit_val))

    # Go through & split out the values for each bit word based on input above:
        for b in bitword_order:
            prev_bit = bits
            bits = bits - b
            i = i + 1
            if i == 1:
                bitword = bit_val[bits:]
               #print(' Bit Word ' + str(i) + ': ' + str(bitword))
                all_bits.append(' Bit Word ' + str(i) + ': ' + str(bitword)) 
            elif i == num_bitwords:
                bitword = bit_val[:prev_bit]
                #print(' Bit Word ' + str(i) + ': ' + str(bitword))
                all_bits.append(' Bit Word ' + str(i) + ': ' + str(bitword))
            else:
                bitword = bit_val[bits:prev_bit]
                #print(' Bit Word ' + str(i) + ': ' + str(bitword))
                all_bits.append(' Bit Word ' + str(i) + ': ' + str(bitword))

    # 2, 4, 5, 6 are the bits used. All 4 should = 0 if no clouds, cloud shadows were present, and pixel is not snow/ice/water
        if int(all_bits[2].split(': ')[-1]) + int(all_bits[4].split(': ')[-1]) + \
        int(all_bits[5].split(': ')[-1]) + int(all_bits[6].split(': ')[-1]) + int(all_bits[3].split(': ')[-1])==0: #
            goodQuality.append(v)
    return goodQuality

# %%
import glob
list_of_files=[]
list_of_tiles=[]
list_of_bands=[]

#input_dir='/data_external/HLS/CA/S30/2022/11/S/L/B/**/'
for f in glob.glob(os.path.join(input_dir+file_filter_pattern), recursive=True):
    logging.debug(f)
    if f[-34:-28] not in list_of_tiles:
        list_of_tiles.append(f[-34:-28])
    if f[-7:-4] not in list_of_bands:
        list_of_bands.append(f[-7:-4])
    list_of_files.append(f)

logging.debug('list_of_files' + str(list_of_files))
logging.debug('list_of_tiles' + str(list_of_tiles))
logging.debug('list_of_bands' + str(list_of_bands))
# Out:
# 2023-06-21 17:11:09,324 - root - DEBUG - /home/romeokienzler/Downloads/HLS2022/HLS/month=06/HLS.S30.T15STU.2022171T165901.v2.0.B01.tif
# 2023-06-21 17:11:09,329 - root - DEBUG - list_of_files['/home/romeokienzler/Downloads/HLS2022/HLS/month=06/HLS.S30.T15STU.2022171T165901.v2.0.B01.tif']
# 2023-06-21 17:11:09,332 - root - DEBUG - list_of_tiles['T15STU']
# 2023-06-21 17:11:09,334 - root - DEBUG - list_of_bands['B01']

# %%
list_of_masks=[]
for f in glob.glob(os.path.join(input_dir+'HLS.S30*Fmask.tif'), recursive=True):
    #print(f,f[-9:-4],f[-34:-28])
    list_of_masks.append(f)

# %%
list_of_files1=[]
list_of_masks1=[]


for j in list_of_tiles:
        for i in list_of_bands:
            list_of_files1=[]
            list_of_masks1=[]
            for f in glob.glob(os.path.join(input_dir+'HLS.S30.'+str(j)+'*'+str(i)+'.tif'), recursive=True):
                list_of_files1.append(f)
            for f in glob.glob(os.path.join(input_dir+'HLS.S30.'+str(j)+'*Fmask.tif'), recursive=True):    
                list_of_masks1.append(f)
            
            goodQuality= good_quality(list_of_files1, list_of_masks1)
            
            stacked_list=process_bands(list_of_files1,crop_layer=None, stack=True)
            stacked_masks=process_bands(list_of_masks1,crop_layer=None, stack=True)
            cf_band_all = np.ma.MaskedArray(stacked_list, np.in1d(stacked_masks, goodQuality, invert=True))  # Apply QA mask to the EVI data
            cf_band_all = np.ma.filled(cf_band_all, np.nan)
            cf_band_all[np.isnan(cf_band_all)] = 0
            cf=cf_band_all[0]
            #sequentially pick cloud free pixel values 
            for i in np.arange(len(stacked_list)-1):  #remove the cloud contaminated pixels
                cf=xr.where((cf==0),cf_band_all[i+1],cf)
            
            #write the array back as tiff files
            
            src=rio.open(list_of_files1[0])
            with rio.Env():

                # Write an array as a raster band to a new 8-bit file. For
                # the new file's profile, we start with the profile of the source
                profile = src.profile

                # And then change the band count to 1, set the
                # dtype to uint16, and specify LZW compression.
                profile.update(
                        dtype=rio.int16,
                        count=1,
                        compress='lzw')
            originalName = list_of_files1[1].rsplit('/', 1)[-1]
            outName = outName = f"{originalName.split('.tif')[0]}"[0:19] +str('08')+ originalName[-8:]
            with rio.open(os.path.join(output_dir+outName), 'w', **profile) as dst:
                dst.write(cf.astype(rio.int16), 1)
# Out:
# 2023-06-21 17:11:13,856 - rasterio.env - DEBUG - Entering env context: <rasterio.env.Env object at 0x7f85782d7ac0>
# 2023-06-21 17:11:13,859 - rasterio.env - DEBUG - Starting outermost env
# 2023-06-21 17:11:13,861 - rasterio.env - DEBUG - No GDAL environment exists
# 2023-06-21 17:11:13,864 - rasterio.env - DEBUG - New GDAL environment <rasterio._env.GDALEnv object at 0x7f8578468d90> created
# 2023-06-21 17:11:13,877 - rasterio._filepath - DEBUG - Installing FilePath filesystem handler plugin...
# 2023-06-21 17:11:13,880 - rasterio._env - DEBUG - GDAL data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/gdal_data'.
# 2023-06-21 17:11:13,883 - rasterio._env - DEBUG - PROJ data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/proj_data'.
# 2023-06-21 17:11:13,885 - rasterio._env - DEBUG - Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x7f8578468d90>.
# 2023-06-21 17:11:13,888 - rasterio.env - DEBUG - Entered env context: <rasterio.env.Env object at 0x7f85782d7ac0>
# 2023-06-21 17:11:13,890 - rasterio._base - DEBUG - Sharing flag: 0
# 2023-06-21 17:11:13,964 - rasterio._base - DEBUG - Nodata success: 1, Nodata value: -9999.000000
# 2023-06-21 17:11:13,968 - rasterio._base - DEBUG - Dataset <open DatasetReader name='/home/romeokienzler/Downloads/HLS2022/HLS/month=06/HLS.S30.T15STU.2022154T170901.v2.0.B01.tif' mode='r'> is started.
# 2023-06-21 17:11:13,971 - rasterio.env - DEBUG - Exiting env context: <rasterio.env.Env object at 0x7f85782d7ac0>
# 2023-06-21 17:11:13,975 - rasterio.env - DEBUG - Cleared existing <rasterio._env.GDALEnv object at 0x7f8578468d90> options
# 2023-06-21 17:11:13,977 - rasterio._env - DEBUG - Stopped GDALEnv <rasterio._env.GDALEnv object at 0x7f8578468d90>.
# 2023-06-21 17:11:13,979 - rasterio.env - DEBUG - Exiting outermost env
# 2023-06-21 17:11:13,981 - rasterio.env - DEBUG - Exited env context: <rasterio.env.Env object at 0x7f85782d7ac0>
# 2023-06-21 17:11:14,018 - rasterio.env - DEBUG - Entering env context: <rasterio.env.Env object at 0x7f85782d6aa0>
# 2023-06-21 17:11:14,020 - rasterio.env - DEBUG - Starting outermost env
# 2023-06-21 17:11:14,022 - rasterio.env - DEBUG - No GDAL environment exists
# 2023-06-21 17:11:14,027 - rasterio.env - DEBUG - New GDAL environment <rasterio._env.GDALEnv object at 0x7f857846bcd0> created
# 2023-06-21 17:11:14,030 - rasterio._env - DEBUG - GDAL data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/gdal_data'.
# 2023-06-21 17:11:14,034 - rasterio._env - DEBUG - PROJ data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/proj_data'.
# 2023-06-21 17:11:14,036 - rasterio._env - DEBUG - Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x7f857846bcd0>.
# 2023-06-21 17:11:14,040 - rasterio.env - DEBUG - Entered env context: <rasterio.env.Env object at 0x7f85782d6aa0>
# 2023-06-21 17:11:14,042 - rasterio._base - DEBUG - Sharing flag: 0
# 2023-06-21 17:11:14,051 - rasterio._base - DEBUG - Nodata success: 1, Nodata value: -9999.000000
# 2023-06-21 17:11:14,053 - rasterio._base - DEBUG - Dataset <open DatasetReader name='/home/romeokienzler/Downloads/HLS2022/HLS/month=06/HLS.S30.T15STU.2022161T165901.v2.0.B01.tif' mode='r'> is started.
# 2023-06-21 17:11:14,058 - rasterio.env - DEBUG - Exiting env context: <rasterio.env.Env object at 0x7f85
- rasterio.env - DEBUG - Exiting env context: <rasterio.env.Env object at 0x7f8578109bd0>
# 2023-06-21 17:11:45,559 - rasterio.env - DEBUG - Cleared existing <rasterio._env.GDALEnv object at 0x7f85782bebc0> options
# 2023-06-21 17:11:45,561 - rasterio._env - DEBUG - Stopped GDALEnv <rasterio._env.GDALEnv object at 0x7f85782bebc0>.
# 2023-06-21 17:11:45,563 - rasterio.env - DEBUG - Exiting outermost env
# 2023-06-21 17:11:45,565 - rasterio.env - DEBUG - Exited env context: <rasterio.env.Env object at 0x7f8578109bd0>
# 2023-06-21 17:11:45,611 - rasterio.env - DEBUG - Entering env context: <rasterio.env.Env object at 0x7f8578108430>
# 2023-06-21 17:11:45,614 - rasterio.env - DEBUG - Starting outermost env
# 2023-06-21 17:11:45,616 - rasterio.env - DEBUG - No GDAL environment exists
# 2023-06-21 17:11:45,620 - rasterio.env - DEBUG - New GDAL environment <rasterio._env.GDALEnv object at 0x7f85782bcdf0> created
# 2023-06-21 17:11:45,626 - rasterio._env - DEBUG - GDAL data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/gdal_data'.
# 2023-06-21 17:11:45,630 - rasterio._env - DEBUG - PROJ data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/proj_data'.
# 2023-06-21 17:11:45,633 - rasterio._env - DEBUG - Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x7f85782bcdf0>.
# 2023-06-21 17:11:45,638 - rasterio.env - DEBUG - Entered env context: <rasterio.env.Env object at 0x7f8578108430>
# 2023-06-21 17:11:45,640 - rasterio._base - DEBUG - Sharing flag: 0
# 2023-06-21 17:11:45,649 - rasterio._base - DEBUG - Nodata success: 1, Nodata value: 255.000000
# 2023-06-21 17:11:45,652 - rasterio._base - DEBUG - Dataset <open DatasetReader name='/home/romeokienzler/Downloads/HLS2022/HLS/month=06/HLS.S30.T15STU.2022179T170859.v2.0.Fmask.tif' mode='r'> is started.
# 2023-06-21 17:11:45,655 - rasterio.env - DEBUG - Exiting env context: <rasterio.env.Env object at 0x7f8578108430>
# 2023-06-21 17:11:45,660 - rasterio.env - DEBUG - Cleared existing <rasterio._env.GDALEnv object at 0x7f85782bcdf0> options
# 2023-06-21 17:11:45,663 - rasterio._env - DEBUG - Stopped GDALEnv <rasterio._env.GDALEnv object at 0x7f85782bcdf0>.
# 2023-06-21 17:11:45,667 - rasterio.env - DEBUG - Exiting outermost env
# 2023-06-21 17:11:45,671 - rasterio.env - DEBUG - Exited env context: <rasterio.env.Env object at 0x7f8578108430>
# I'm stacking your data now.
# 2023-06-21 17:11:45,731 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:45,735 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:45,739 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:45,742 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:45,745 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:45,747 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:45,749 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:45,935 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:46,049 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:46,052 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:46,055 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:46,058 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:46,060 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:46,064 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:46,068 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:46,290 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:46,348 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:46,352 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:46,355 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:46,357 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:46,360 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:46,363 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:46,365 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:46,557 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:46,660 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:46,662 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:46,665 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:46,667 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:46,672 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:46,674 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:46,676 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:46,869 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:46,945 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:46,947 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:46,950 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:46,952 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:46,954 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:46,957 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:46,959 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:47,191 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:47,295 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:47,297 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:47,300 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:47,302 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:47,304 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:47,309 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:47,311 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:47,509 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:47,547 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:47,551 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:47,553 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:47,558 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:47,560 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:47,562 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:47,564 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:47,761 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:47,879 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:47,882 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:47,885 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:47,887 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:47,891 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:47,893 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:47,897 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:48,111 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:48,162 - rasterio._io - DEBUG - Output nodata value read from file: 255.0
# 2023-06-21 17:11:48,165 - rasterio._io - DEBUG - Output nodata values: [255.0]
# 2023-06-21 17:11:48,168 - rasterio._io - DEBUG - all_valid: False
# 2023-06-21 17:11:48,171 - rasterio._io - DEBUG - mask_flags: ([<MaskFlags.nodata: 8>],)
# 2023-06-21 17:11:48,172 - rasterio._io - DEBUG - Jump straight to _read()
# 2023-06-21 17:11:48,175 - rasterio._io - DEBUG - Window: Window(col_off=0, row_off=0, width=3660, height=3660)
# 2023-06-21 17:11:48,181 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:48,370 - rasterio._io - DEBUG - IO window xoff=0.0 yoff=0.0 width=3660.0 height=3660.0
# 2023-06-21 17:11:51,055 - rasterio.env - DEBUG - Entering env context: <rasterio.env.Env object at 0x7f85782bc580>
# 2023-06-21 17:11:51,058 - rasterio.env - DEBUG - Starting outermost env
# 2023-06-21 17:11:51,060 - rasterio.env - DEBUG - No GDAL environment exists
# 2023-06-21 17:11:51,064 - rasterio.env - DEBUG - New GDAL environment <rasterio._env.GDALEnv object at 0x7f85782bc700> created
# 2023-06-21 17:11:51,067 - rasterio._env - DEBUG - GDAL data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/gdal_data'.
# 2023-06-21 17:11:51,069 - rasterio._env - DEBUG - PROJ data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/proj_data'.
# 2023-06-21 17:11:51,073 - rasterio._env - DEBUG - Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x7f85782bc700>.
# 2023-06-21 17:11:51,075 - rasterio.env - DEBUG - Entered env context: <rasterio.env.Env object at 0x7f85782bc580>
# 2023-06-21 17:11:51,078 - rasterio._base - DEBUG - Sharing flag: 0
# 2023-06-21 17:11:51,089 - rasterio._base - DEBUG - Nodata success: 1, Nodata value: -9999.000000
# 2023-06-21 17:11:51,093 - rasterio._base - DEBUG - Dataset <open DatasetReader name='/home/romeokienzler/Downloads/HLS2022/HLS/month=06/HLS.S30.T15STU.2022154T170901.v2.0.B01.tif' mode='r'> is started.
# 2023-06-21 17:11:51,095 - rasterio.env - DEBUG - Exiting env context: <rasterio.env.Env object at 0x7f85782bc580>
# 2023-06-21 17:11:51,097 - rasterio.env - DEBUG - Cleared existing <rasterio._env.GDALEnv object at 0x7f85782bc700> options
# 2023-06-21 17:11:51,100 - rasterio._env - DEBUG - Stopped GDALEnv <rasterio._env.GDALEnv object at 0x7f85782bc700>.
# 2023-06-21 17:11:51,102 - rasterio.env - DEBUG - Exiting outermost env
# 2023-06-21 17:11:51,109 - rasterio.env - DEBUG - Exited env context: <rasterio.env.Env object at 0x7f85782bc580>
# 2023-06-21 17:11:51,112 - rasterio.env - DEBUG - Entering env context: <rasterio.env.Env object at 0x7f8578468c70>
# 2023-06-21 17:11:51,117 - rasterio.env - DEBUG - Starting outermost env
# 2023-06-21 17:11:51,121 - rasterio.env - DEBUG - No GDAL environment exists
# 2023-06-21 17:11:51,123 - rasterio.env - DEBUG - New GDAL environment <rasterio._env.GDALEnv object at 0x7f8578108df0> created
# 2023-06-21 17:11:51,127 - rasterio._env - DEBUG - GDAL data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/gdal_data'.
# 2023-06-21 17:11:51,129 - rasterio._env - DEBUG - PROJ data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/proj_data'.
# 2023-06-21 17:11:51,134 - rasterio._env - DEBUG - Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x7f8578108df0>.
# 2023-06-21 17:11:51,137 - rasterio.env - DEBUG - Entered env context: <rasterio.env.Env object at 0x7f8578468c70>
# 2023-06-21 17:11:51,141 - rasterio.env - DEBUG - Exiting env context: <rasterio.env.Env object at 0x7f8578468c70>
# 2023-06-21 17:11:51,144 - rasterio.env - DEBUG - Cleared existing <rasterio._env.GDALEnv object at 0x7f8578108df0> options
# 2023-06-21 17:11:51,146 - rasterio._env - DEBUG - Stopped GDALEnv <rasterio._env.GDALEnv object at 0x7f8578108df0>.
# 2023-06-21 17:11:51,149 - rasterio.env - DEBUG - Exiting outermost env
# 2023-06-21 17:11:51,151 - rasterio.env - DEBUG - Exited env context: <rasterio.env.Env object at 0x7f8578468c70>
# 2023-06-21 17:11:51,153 - rasterio.env - DEBUG - Entering env context: <rasterio.env.Env object at 0x7f85782bc700>
# 2023-06-21 17:11:51,157 - rasterio.env - DEBUG - Starting outermost env
# 2023-06-21 17:11:51,159 - rasterio.env - DEBUG - No GDAL environment exists
# 2023-06-21 17:11:51,163 - rasterio.env - DEBUG - New GDAL environment <rasterio._env.GDALEnv object at 0x7f857810bb80> created
# 2023-06-21 17:11:51,167 - rasterio._env - DEBUG - GDAL data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/gdal_data'.
# 2023-06-21 17:11:51,169 - rasterio._env - DEBUG - PROJ data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/proj_data'.
# 2023-06-21 17:11:51,172 - rasterio._env - DEBUG - Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x7f857810bb80>.
# 2023-06-21 17:11:51,178 - rasterio.env - DEBUG - Entered env context: <rasterio.env.Env object at 0x7f85782bc700>
# 2023-06-21 17:11:51,182 - rasterio._io - DEBUG - Path: _UnparsedPath(path='/home/romeokienzler/Downloads/HLSS30.CF2/HLS.S30.T15STU.202208.B01.tif'), mode: w, driver: GTiff
# 2023-06-21 17:11:51,205 - rasterio._base - DEBUG - Nodata success: 1, Nodata value: -9999.000000
# 2023-06-21 17:11:51,207 - rasterio.env - DEBUG - Exiting env context: <rasterio.env.Env object at 0x7f85782bc700>
# 2023-06-21 17:11:51,210 - rasterio.env - DEBUG - Cleared existing <rasterio._env.GDALEnv object at 0x7f857810bb80> options
# 2023-06-21 17:11:51,212 - rasterio._env - DEBUG - Stopped GDALEnv <rasterio._env.GDALEnv object at 0x7f857810bb80>.
# 2023-06-21 17:11:51,214 - rasterio.env - DEBUG - Exiting outermost env
# 2023-06-21 17:11:51,217 - rasterio.env - DEBUG - Exited env context: <rasterio.env.Env object at 0x7f85782bc700>
# 2023-06-21 17:11:51,221 - rasterio.env - DEBUG - Entering env context: <rasterio.env.Env object at 0x7f85782d5810>
# 2023-06-21 17:11:51,224 - rasterio.env - DEBUG - Starting outermost env
# 2023-06-21 17:11:51,226 - rasterio.env - DEBUG - No GDAL environment exists
# 2023-06-21 17:11:51,230 - rasterio.env - DEBUG - New GDAL environment <rasterio._env.GDALEnv object at 0x7f857810bb80> created
# 2023-06-21 17:11:51,233 - rasterio._env - DEBUG - GDAL data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/gdal_data'.
# 2023-06-21 17:11:51,235 - rasterio._env - DEBUG - PROJ data found in package: path='/home/romeokienzler/gitco/component-library/.venv/lib64/python3.10/site-packages/rasterio/proj_data'.
# 2023-06-21 17:11:51,237 - rasterio._env - DEBUG - Started GDALEnv: self=<rasterio._env.GDALEnv object at 0x7f857810bb80>.
# 2023-06-21 17:11:51,239 - rasterio.env - DEBUG - Entered env context: <rasterio.env.Env object at 0x7f85782d5810>
# 2023-06-21 17:11:52,641 - rasterio.env - DEBUG - Exiting env context: <rasterio.env.Env object at 0x7f85782d5810>
# 2023-06-21 17:11:52,645 - rasterio.env - DEBUG - Cleared existing <rasterio._env.GDALEnv object at 0x7f857810bb80> options
# 2023-06-21 17:11:52,647 - rasterio._env - DEBUG - Stopped GDALEnv <rasterio._env.GDALEnv object at 0x7f857810bb80>.
# 2023-06-21 17:11:52,656 - rasterio.env - DEBUG - Exiting outermost env
# 2023-06-21 17:11:52,660 - rasterio.env - DEBUG - Exited env context: <rasterio.env.Env object at 0x7f85782d5810>

# %% [markdown]
# For mean or max calculations, same iterations but replace
# "for i in np.arange(len(stacked_list)-1):
#                 cf=xr.where((cf==0),cf_band_all[i+1],cf)""
#
# with "cf=cf_band_all.mean(axis=0) or cf_band_all.max(axis=0) "
