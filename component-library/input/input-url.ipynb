# %% [markdown]
# # Input URL

# %% [markdown]
# This component reads a file from a HTTP(s) source via wget

# %%
# !pip install wget==3.2
# Out:
# Requirement already satisfied: wget==3.2 in /home/romeokienzler/gitco/new_horizons/elyra/venv/lib/python3.8/site-packages (3.2)
# WARNING: You are using pip version 19.3.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import logging
import os
import re
import sys
import wget

# %%
# path and file name for output
output_data_csv = os.environ.get('output_data_csv', 'data.csv')

# url of souce
url = os.environ.get('url')

# temporal data storage for local execution
data_dir = os.environ.get('data_dir', '../../data/')

# %%
parameters = list(
    map(lambda s: re.sub('$', '"', s),
        map(
            lambda s: s.replace('=', '="'),
            filter(
                lambda s: s.find('=') > -1 and bool(re.match(r'[A-Za-z0-9_]*=[.\/A-Za-z0-9]*', s)),
                sys.argv
            )
    )))

for parameter in parameters:
    logging.warning('Parameter: ' + parameter)
    exec(parameter)

# %%
destination = os.path.join(data_dir, output_data_csv)
os.remove(destination) if os.path.exists(destination) else None
wget.download(url, out=destination)
# Out:
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# -1 / unknown
# '../../data/data.csv'

# %%
print('Data written successfully')
# Out:
# Data written successfully
